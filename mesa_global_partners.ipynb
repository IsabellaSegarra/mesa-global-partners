# %% [markdown]
# # Multinational Exchange for Sustainable Agriculture Global Partners

# %%
# Library set up
import pandas as pd # for data wrangling
import numpy as np  # for data wrangling 
import folium as folium

# %%
# Import csv 
global_partners = pd.read_csv('data/MESA Global Partners - Sheet1.csv')

# %%
# View csv
global_partners.head()
# Out:
#                                             Name Abbreviation  \
# 0                          Asian Rural Institute          ARI
# 1                               Grow West Africa          GWA
# 2  Grow Biointensive Agriculture Center of Kenya      G-BiACK
# 3                             Kola Nut Producers          NaN
# 4            Lanka Organic Agricultural Movement         LOAM
#
#                                                 Link       Region  \
# 0                         https://ari.ac.jp/en/home/    East Asia
# 1           https://www.facebook.com/growwestafrica/  West Africa
# 2                               https://g-biack.org/  East Africa
# 3  https://kolanutproducersassociationsl.com/abou...  West Africa
# 4                                   https://loam.lk/   South Asia
#
#                                    Coords   latitude   longitude
# 0     36.8949993741806, 140.0031364404829  36.894999  140.003136
# 1   7.779562601846972, -2.082983542326861   7.779563   -2.082984
# 2  -1.0680363027679969, 37.17425215302288  -1.068036   37.174252
# 3    7.86376225293142, -11.19592659212945   7.863762  -11.195927
# 4     6.85910918281852, 79.90956937590484   6.859109   79.909569

# %%
# Data cleaning - get rid of trailing spaces 
global_partners.columns = global_partners.columns.str.strip()
global_partners = global_partners.apply(lambda col: col.str.strip() if col.dtype == "object" else col)

# %%
# Initiate folium map
m = folium.Map(location=[10, 20], zoom_start=2, 
               tiles="https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}",
    attr="Esri")

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f5cce5c53bd8fa6190a68ca30503df4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f5cce5c53bd8fa6190a68ca30503df4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f5cce5c53bd8fa6190a68ca30503df4 = L.map(
#                 &quot;map_9f5cce5c53bd8fa6190a68ca30503df4&quot;,
#                 {
#                     center: [10.0, 20.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e5b7ebed3224022342c1e10738c9c2e = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Esri&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e5b7ebed3224022342c1e10738c9c2e.addTo(map_9f5cce5c53bd8fa6190a68ca30503df4);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
for _, row in global_partners.iterrows():
    # Account for rows w/o abbreviation
    label = row["Abbreviation"] if pd.notna(row["Abbreviation"]) and row["Abbreviation"] else row["Name"]
    # create popup to website
    popup_html = f'<b>{row["Name"]}</b><br>{row["Region"]}<br><a href="{row["Link"]}" target="_blank">Visit website</a>'
    # pop-up marker
    folium.Marker(
        location=[row["latitude"], row["longitude"]],
        popup=folium.Popup(popup_html, max_width=250),
        tooltip=label,
    ).add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f5cce5c53bd8fa6190a68ca30503df4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f5cce5c53bd8fa6190a68ca30503df4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f5cce5c53bd8fa6190a68ca30503df4 = L.map(
#                 &quot;map_9f5cce5c53bd8fa6190a68ca30503df4&quot;,
#                 {
#                     center: [10.0, 20.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e5b7ebed3224022342c1e10738c9c2e = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Esri&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e5b7ebed3224022342c1e10738c9c2e.addTo(map_9f5cce5c53bd8fa6190a68ca30503df4);
#
#
#             tile_layer_9e5b7ebed3224022342c1e10738c9c2e.addTo(map_9f5cce5c53bd8fa6190a68ca30503df4);
#
#
#             var marker_e1583fda0c28eb406ca43133efb62c55 = L.marker(
#                 [36.89499937, 140.0031364],
#                 {
# }
#             ).addTo(map_9f5cce5c53bd8fa6190a68ca30503df4);
#
#
#         var popup_1168e616d771dafd79b1229903cf5f6e = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_212ef7ced36b14258adfd5e23c5f5499 = $(`&lt;div id=&quot;html_212ef7ced36b14258adfd5e23c5f5499&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Asian Rural Institute&lt;/b&gt;&lt;br&gt;East Asia&lt;br&gt;&lt;a href=&quot;https://ari.ac.jp/en/home/&quot; target=&quot;_blank&quot;&gt;Visit website&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_1168e616d771dafd79b1229903cf5f6e.setContent(html_212ef7ced36b14258adfd5e23c5f5499);
#
#
#
#         marker_e1583fda0c28eb406ca43133efb62c55.bindPopup(popup_1168e616d771dafd79b1229903cf5f6e)
#         ;
#
#
#
#
#             marker_e1583fda0c28eb406ca43133efb62c55.bindTooltip(
#                 `&lt;div&gt;
#                      ARI
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_6a0195cf39612738ad5abc63856b055b = L.marker(
#                 [7.779562602, -2.082983542],
#                 {
# }
#             ).addTo(map_9f5cce5c53bd8fa6190a68ca30503df4);
#
#
#         var popup_e89abc0aa1ae87a5e4fd1d1b083f1cfc = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_16852b814c3b03b9a9a02abe404e93ba = $(`&lt;div id=&quot;html_16852b814c3b03b9a9a02abe404e93ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Grow West Africa&lt;/b&gt;&lt;br&gt;West Africa&lt;br&gt;&lt;a href=&quot;https://www.facebook.com/growwestafrica/&quot; target=&quot;_blank&quot;&gt;Visit website&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_e89abc0aa1ae87a5e4fd1d1b083f1cfc.setContent(html_16852b814c3b03b9a9a02abe404e93ba);
#
#
#
#         marker_6a0195cf39612738ad5abc63856b055b.bindPopup(popup_e89abc0aa1ae87a5e4fd1d1b083f1cfc)
#         ;
#
#
#
#
#             marker_6a0195cf39612738ad5abc63856b055b.bindTooltip(
#                 `&lt;div&gt;
#                      GWA
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_de86f1faf0f0b7945396025cd3bed29a = L.marker(
#                 [-1.068036303, 37.17425215],
#                 {
# }
#             ).addTo(map_9f5cce5c53bd8fa6190a68ca30503df4);
#
#
#         var popup_e72dfc143b1b7385f66aa92287d71148 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_99b015c92febdd426b0e9d88682ab768 = $(`&lt;div id=&quot;html_99b015c92febdd426b0e9d88682ab768&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Grow Biointensive Agriculture Center of Kenya&lt;/b&gt;&lt;br&gt;East Africa&lt;br&gt;&lt;a href=&quot;https://g-biack.org/&quot; target=&quot;_blank&quot;&gt;Visit website&lt;/a&gt;&lt;/div&gt;`)[0];
#                 popup_e72dfc143b1b7385f66aa92287d71148.setContent(html_99b015c92febdd426b0e9d88682ab768);
#
#
#
#         marker_de86f1faf0f0b7945396025cd3bed29a.bindPopup(popup_e72dfc143b1b7385f66aa92287d71148)
#         ;
#
#
#
#
#             marker_de86f1faf0f0b7945396025cd3bed29a.bindTooltip(
#                 `&lt;div&gt;
#                      G-BiACK
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_0cb6070a27bf800cef8bffadbe044292 = L.marker(
#                 [7.863762253, -11.19592659],
#                 {
# }
#             ).addTo(map_9f5cce5c53bd8fa6190a68ca30503df4);
#
#
#         var popup_afe2055d30db7a026b5e4252593c6fd1 = L.popup({
#   &quot;maxWidth
